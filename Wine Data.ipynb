# %% [markdown]
# https://www.winemag.com/?s=&drink_type=wine&page=1&search_type=reviews

# %%
from bs4 import NavigableString, Comment
from bs4 import BeautifulSoup
import os
import pandas as pd
import requests

# %% [markdown]
# ## Gather

# %%
URL = 'https://www.wine.com/list/wine/7155?ratingmin=94#'

# %%
# this is the datafram with all 
# this will be the list containing all the scraped information

web_data = []

def get_info(all_li):
    for li in all_li:
        product_name = li.find('span', class_= 'prodItemInfo_name').string
        price = li.find('span', class_='productPrice_price-regWhole').string
        varietal = li.find('span', class_='prodItemInfo_varietal').string
        origin = li.find('span', class_='prodItemInfo_originText').string
        rating = li.find('span', class_='averageRating_average').string
        rating_count = li.find('span', class_='averageRating_number').string
        web_data.append({'product_name' : product_name,
                    'price': price,
                    'varietal': varietal,
                    'origin': origin,
                    'rating': rating,
                    'rating_count': rating_count})

# %% [markdown]
# ## Pagination Stuff

# %%
url_df = []

def url_contructor(page_number, url):
    first = URL.split('7155', 1)[0]
    second = URL.split('7155',1)[1]
    url = first + '7155/' + str(page_number) + second
    url_df.append(url)

# %%
def pagination():
    page = 0
    URL = 'https://www.wine.com/list/wine/7155?ratingmin=94#'
    for x in range(1, 3):
        try:
            page += 1
            url_contructor(page, URL)
        except Exception:
            print(Exception)

# %% [markdown]
# ## Link it all together

# %%
def main_execute():
    pagination()
    for link in url_df:
        page = requests.get(link)
        soup = BeautifulSoup(page.content, 'html.parser')
        all_li = soup.find_all('li', {'class': 'prodItem'})
        get_info(all_li)

# %%
main_execute()

# %%
web_data
# Out:
# [{'product_name': 'Dom Perignon Vintage with Gift Box 2010',
#   'price': '199',
#   'varietal': 'Vintage Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '4.5',
#   'rating_count': '42'},
#  {'product_name': 'Veuve Clicquot Yellow Label Brut',
#   'price': '59',
#   'varietal': 'Non-Vintage Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '4.4',
#   'rating_count': '1138'},
#  {'product_name': 'Duckhorn Napa Valley Cabernet Sauvignon 2017',
#   'price': '78',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '4.3',
#   'rating_count': '62'},
#  {'product_name': 'Caymus Special Selection Cabernet Sauvignon 2016',
#   'price': '180',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '4.6',
#   'rating_count': '108'},
#  {'product_name': 'Quintessa 2016',
#   'price': '199',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Rutherford, Napa Valley, California',
#   'rating': '4.7',
#   'rating_count': '73'},
#  {'product_name': 'Joseph Phelps Insignia 2016',
#   'price': '300',
#   'varietal': 'Bordeaux Red Blends',
#   'origin': 'Napa Valley, California',
#   'rating': '4.6',
#   'rating_count': '81'},
#  {'product_name': 'Opus One 2017',
#   'price': '364',
#   'varietal': 'Bordeaux Red Blends',
#   'origin': 'Oakville, Napa Valley, California',
#   'rating': '4.2',
#   'rating_count': '8'},
#  {'product_name': 'Trefethen Cabernet Sauvignon 2017',
#   'price': '65',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Oak Knoll District, Napa Valley, California',
#   'rating': '4.3',
#   'rating_count': '65'},
#  {'product_name': 'Dom Perignon Vintage 2010',
#   'price': '189',
#   'varietal': 'Vintage Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '4.8',
#   'rating_count': '10'},
#  {'product_name': 'Antinori Tignanello 2017',
#   'price': '129',
#   'varietal': 'Tuscan Blends',
#   'origin': 'Tuscany, Italy',
#   'rating': '4.9',
#   'rating_count': '45'},
#  {'product_name': 'Robert Mondavi To Kalon Vineyard Reserve Cabernet Sauvignon 2016',
#   'price': '175',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Oakville, Napa Valley, California',
#   'rating': '4.2',
#   'rating_count': '50'},
#  {'product_name': 'Bollinger Brut Special Cuvee',
#   'price': '79',
#   'varietal': 'Non-Vintage Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '4.3',
#   'rating_count': '394'},
#  {'product_name': 'Mazzei Chianti Classico Riserva Ser Lapo 2016',
#   'price': '37',
#   'varietal': 'Sangiovese',
#   'origin': 'Chianti Classico, Chianti, Tuscany, Italy',
#   'rating': '4.0',
#   'rating_count': '672'},
#  {'product_name': 'Veuve Clicquot La Grande Dame with Gift Box 2008',
#   'price': '189',
#   'varietal': 'Vintage Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '4.6',
#   'rating_count': '31'},
#  {'product_name': 'Ulysses Cabernet Sauvignon 2016',
#   'price': '219',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '0.0',
#   'rating_count': '0'},
#  {'product_name': "Stags' Leap Winery The Leap Estate Grown Cabernet Sauvignon 2016",
#   'price': '110',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Stags Leap District, Napa Valley, California',
#   'rating': '4.4',
#   'rating_count': '34'},
#  {'product_name': 'Beringer Private Reserve Cabernet Sauvignon 2015',
#   'price': '170',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '4.5',
#   'rating_count': '41'},
#  {'product_name': 'Laurent-Perrier Cuvee Rose',
#   'price': '100',
#   'varietal': 'Rosé Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '4.6',
#   'rating_count': '306'},
#  {'product_name': 'The Prisoner Wine Company Cuttings 2017',
#   'price': '55',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '4.4',
#   'rating_count': '308'},
#  {'product_name': 'Dominus Estate 2016',
#   'price': '299',
#   'varietal': 'Bordeaux Red Blends',
#   'origin': 'Yountville, Napa Valley, California',
#   'rating': '4.4',
#   'rating_count': '77'},
#  {'product_name': 'Bella Union by Far Niente Cabernet Sauvignon 2017',
#   'price': '80',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '4.3',
#   'rating_count': '156'},
#  {'product_name': 'Taittinger Comtes de Champagne Blanc de Blancs 2008',
#   'price': '209',
#   'varietal': 'Vintage Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '0.0',
#   'rating_count': '0'},
#  {'product_name': 'Shafer Hillside Select Cabernet Sauvignon 2015',
#   'price': '310',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Stags Leap District, Napa Valley, California',
#   'rating': '4.7',
#   'rating_count': '23'},
#  {'product_name': 'Chateau Pontet-Canet 2016',
#   'price': '169',
#   'varietal': 'Bordeaux Red Blends',
#   'origin': 'Pauillac, Bordeaux, France',
#   'rating': '4.3',
#   'rating_count': '32'},
#  {'product_name': 'Louis Roederer Cristal Brut with Gift Box 2012',
#   'price': '289',
#   'varietal': 'Vintage Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '4.9',
#   'rating_count': '16'},
#  {'product_name': 'Cristom Mt. Jefferson Cuvee Pinot Noir 2018',
#   'price': '32',
#   'varietal': 'Pinot Noir',
#   'origin': 'Eola-Amity Hills, Willamette Valley, Oregon',
#   'rating': '4.1',
#   'rating_count': '97'},
#  {'product_name': 'Argiano Brunello di Montalcino 2015',
#   'price': '75',
#   'varietal': 'Sangiovese',
#   'origin': 'Montalcino, Tuscany, Italy',
#   'rating': '4.3',
#   'rating_count': '169'},
#  {'product_name': 'G.D. Vajra Barolo Albe 2016',
#   'price': '40',
#   'varietal': 'Nebbiolo',
#   'origin': 'Barolo, Piedmont, Italy',
#   'rating': '4.1',
#   'rating_count': '49'},
#  {'product_name': 'Heitz Cellar Napa Valley Cabernet Sauvignon 2015',
#   'price': '57',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '4.1',
#   'rating_count': '64'},
#  {'product_name': 'Trefethen Estate Chardonnay 2018',
#   'price': '38',
#   'varietal': 'Chardonnay',
#   'origin': 'Oak Knoll District, Napa Valley, California',
#   'rating': '4.0',
#   'rating_count': '82'},
#  {'product_name': 'Hall Coeur Cabernet Sauvignon 2016',
#   'price': '70',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'St. Helena, Napa Valley, California',
#   'rating': '4.4',
#   'rating_count': '26'},
#  {'product_name': 'Freemark Abbey Napa Valley Cabernet Sauvignon 2016',
#   'price': '60',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '4.2',
#   'rating_count': '188'},
#  {'product_name': 'Domaine de la Janasse Chateauneuf-du-Pape Vieilles Vignes 2017',
#   'price': '118',
#   'varietal': 'Rhone Red Blends',
#   'origin': 'Chateauneuf-du-Pape, Rhone, France',
#   'rating': '4.0',
#   'rating_count': '14'},
#  {'product_name': 'Austin Hope Cabernet Sauvignon 2018',
#   'price': '54',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Paso Robles, Central Coast, California',
#   'rating': '4.5',
#   'rating_count': '206'},
#  {'product_name': 'Produttori del Barbaresco Barbaresco 2016',
#   'price': '44',
#   'varietal': 'Nebbiolo',
#   'origin': 'Barbaresco, Piedmont, Italy',
#   'rating': '4.3',
#   'rating_count': '238'},
#  {'product_name': 'Castellani Sangiovese 2016',
#   'price': '14',
#   'varietal': 'Sangiovese',
#   'origin': 'Tuscany, Italy',
#   'rating': '4.0',
#   'rating_count': '169'},
#  {'product_name': 'Mayacamas Cabernet Sauvignon 2014',
#   'price': '124',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Mt. Veeder, Napa Valley, California',
#   'rating': '4.1',
#   'rating_count': '67'},
#  {'product_name': 'Louis Roederer Brut Premier',
#   'price': '54',
#   'varietal': 'Non-Vintage Sparkling Wine',
#   'origin': 'Champagne, France',
#   'rating': '4.3',
#   'rating_count': '169'},
#  {'product_name': 'Chateau Rauzan-Segla 2010',
#   'price': '159',
#   'varietal': 'Bordeaux Red Blends',
#   'origin': 'Margaux, Bordeaux, France',
#   'rating': '4.5',
#   'rating_count': '13'},
#  {'product_name': 'Parducci True Grit Reserve Petite Sirah 2018',
#   'price': '30',
#   'varietal': 'Petite Sirah',
#   'origin': 'Mendocino, California',
#   'rating': '4.1',
#   'rating_count': '33'},
#  {'product_name': 'Far Niente Napa Valley Cabernet Sauvignon 2018',
#   'price': '150',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '0.0',
#   'rating_count': '0'},
#  {'product_name': 'Martin Ray Sonoma Coast Pinot Noir 2018',
#   'price': '28',
#   'varietal': 'Pinot Noir',
#   'origin': 'Sonoma Coast, Sonoma County, California',
#   'rating': '3.8',
#   'rating_count': '663'},
#  {'product_name': 'Louis Latour Chateau Corton Grancey Grand Cru 2016',
#   'price': '200',
#   'varietal': 'Pinot Noir',
#   'origin': "Aloxe-Corton, Cote de Beaune, Cote d'Or, Burgundy, France",
#   'rating': '0.0',
#   'rating_count': '0'},
#  {'product_name': 'Pio Cesare Barolo 2016',
#   'price': '82',
#   'varietal': 'Nebbiolo',
#   'origin': 'Barolo, Piedmont, Italy',
#   'rating': '0.0',
#   'rating_count': '0'},
#  {'product_name': 'La Rasina Brunello di Montalcino 2015',
#   'price': '58',
#   'varietal': 'Sangiovese',
#   'origin': 'Montalcino, Tuscany, Italy',
#   'rating': '4.5',
#   'rating_count': '41'},
#  {'product_name': 'Clarendon Hills Astralis Syrah 2011',
#   'price': '200',
#   'varietal': 'Syrah/Shiraz',
#   'origin': 'McLaren Vale, South Australia, Australia',
#   'rating': '4.2',
#   'rating_count': '33'},
#  {'product_name': 'El Enemigo Chardonnay 2018',
#   'price': '24',
#   'varietal': 'Chardonnay',
#   'origin': 'Mendoza, Argentina',
#   'rating': '4.1',
#   'rating_count': '52'},
#  {'product_name': 'Chateau Pontet-Canet 2010',
#   'price': '289',
#   'varietal': 'Bordeaux Red Blends',
#   'origin': 'Pauillac, Bordeaux, France',
#   'rating': '4.4',
#   'rating_count': '51'},
#  {'product_name': 'Faust Cabernet Sauvignon 2018',
#   'price': '55',
#   'varietal': 'Cabernet Sauvignon',
#   'origin': 'Napa Valley, California',
#   'rating': '3.9',
#   'rating_count': '7'},
#  {'product_name': 'Opus One 2007',
#   'price': '449',
#   'varietal': 'Bordeaux Red Blends',
#   'origin': 'Oakville, Napa Valley, California',
#   'rating': '4.7',
#   'rating_count': '16'}]
